# %%
import sqlite3
import pandas as pd
import numpy as np
import plotly.express as px

# %%
# Conectando ao banco
conn = sqlite3.connect(r'/content/vendas_marketing.db')

df_vendas = pd.read_sql('SELECT * FROM Vendas', conn)
df_produtos = pd.read_sql('SELECT * FROM Produtos', conn)
df_campanhas_marketing = pd.read_sql('SELECT * FROM Campanhas_Marketing', conn)
df_clientes = pd.read_sql('SELECT * FROM Clientes', conn)
df_interacoes_marketing = pd.read_sql('SELECT * FROM Interacoes_Marketing', conn)

# %% [markdown]
# # A. Análise de Vendas

# %% [markdown]
# 1. Total de Vendas por Canal:
# Calcule o valor total de vendas por canal de aquisição (Outbound vs Inbound) em um período específico (por exemplo, no último trimestre).

# %%
valor_por_canal = df_vendas['canal_aquisicao'].value_counts()
valor_por_canal
# Out:
# canal_aquisicao
# Outbound    493
# Inbound     492
# Name: count, dtype: int64

# %%
fig = px.pie(
    valor_por_canal,
    names=valor_por_canal.index,
    values=valor_por_canal.values,
    title='Valor Total por Canal de Aquisição'
)
fig.update_traces(textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7db128e9-40d6-45b0-b266-fedec4a88615" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7db128e9-40d6-45b0-b266-fedec4a88615")) {                    Plotly.newPlot(                        "7db128e9-40d6-45b0-b266-fedec4a88615",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"canal_aquisicao=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Outbound","Inbound"],"legendgroup":"","name":"","showlegend":true,"values":[493,492],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0," ...

# %% [markdown]
# ---

# %% [markdown]
# 2. Top Produtos:
# Identifique os 5 produtos com maior volume de vendas e calcule a margem de lucro média para esses produtos.

# %%
# Relacionando as tabelas Vendas com Produtos
vendas_produtos = df_vendas.join(df_produtos.set_index('id_produto'), on='id_produto', how='left')

# Alterando para datetime a coluna data_venda
vendas_produtos['data_venda'] = pd.to_datetime(vendas_produtos['data_venda'])

# %%
# Definindo a coluna id_vendas como index
vendas_produtos.set_index('id_venda', inplace=True)

# %%
# Verificando as infos das tabelas
vendas_produtos.head(5)
# Out:
#           id_cliente  id_produto  id_campanha data_venda  quantidade  \
# id_venda
# 1                273          13          8.0 2025-06-07           4
# 2               4044          21         11.0 2025-07-27          10
# 3                714          19         13.0 2025-10-29           1
# 4               1394           8          7.0 2025-12-01           1
# 5               2644           8         10.0 2025-01-16           1
#
#           valor_total canal_aquisicao             nome_produto    categoria  \
# id_venda
# 1             2623.20         Inbound          GS Engage - Hic         SaaS
# 2             7295.70        Outbound       High Growth - Nisi  Consultoria
# 3              142.35        Outbound  Station AI - Blanditiis         SaaS
# 4              871.78        Outbound      GS Engage - Commodi         SaaS
# 5              871.78        Outbound      GS Engage - Commodi         SaaS
#
#           preco_unitario  custo_unitario
# id_venda
# 1                 655.80          537.76
# 2                 729.57          437.74
# 3                 142.35          106.76
# 4                 871.78          531.79
# 5                 871.78          531.79

# %%
# Inserindo a coluna lucro total
vendas_produtos['lucro_total'] = (vendas_produtos['preco_unitario'] - vendas_produtos['custo_unitario']) * vendas_produtos['quantidade']

# %%
#Validando as informações
vendas_produtos
# Out:
#           id_cliente  id_produto  id_campanha data_venda  quantidade  \
# id_venda
# 1                273          13          8.0 2025-06-07           4
# 2               4044          21         11.0 2025-07-27          10
# 3                714          19         13.0 2025-10-29           1
# 4               1394           8          7.0 2025-12-01           1
# 5               2644           8         10.0 2025-01-16           1
# ...              ...         ...          ...        ...         ...
# 981              416           5          NaN 2025-11-20           5
# 982             4005          11          NaN 2025-04-19          10
# 983             4061           9          NaN 2025-10-09          10
# 984             3299           6          NaN 2025-07-23           3
# 985             1766          22          NaN 2025-12-25           6
#
#           valor_total canal_aquisicao               nome_produto    categoria  \
# id_venda
# 1             2623.20         Inbound            GS Engage - Hic         SaaS
# 2             7295.70        Outbound         High Growth - Nisi  Consultoria
# 3              142.35        Outbound    Station AI - Blanditiis         SaaS
# 4              871.78        Outbound        GS Engage - Commodi         SaaS
# 5              871.78        Outbound        GS Engage - Commodi         SaaS
# ...               ...             ...                        ...          ...
# 981             77.35         Inbound     Station AI - Similique         SaaS
# 982           2324.10         Inbound  Demanda Infinita - Maxime  Treinamento
# 983            401.90        Outbound     GS Engage - Doloremque         SaaS
# 984            920.04        Outbound         High Growth - Quis  Consultoria
# 985           5679.00        Outbound          High Growth - Est  Consultoria
#
#           preco_unitario  custo_unitario  lucro_total
# id_venda
# 1                 655.80          537.76       472.16
# 2                 729.57          437.74      2918.30
# 3                 142.35          106.76        35.59
# 4                 871.78          531.79       339.99
# 5                 871.78          531.79       339.99
# ...                  ...             ...          ...
# 981                15.47            9.59        29.40
# 982               232.41          204.52       278.90
# 983                40.19           29.34       108.50
# 984               306.68          239.21       202.41
# 985               946.50          577.37      2214.78
#
# [985 rows x 12 columns]

# %%
vendas_produtos['margem_lucro'] = (vendas_produtos['lucro_total'] / vendas_produtos['valor_total']) * 100

# %%
vendas_produtos
# Out:
#           id_cliente  id_produto  id_campanha data_venda  quantidade  \
# id_venda
# 1                273          13          8.0 2025-06-07           4
# 2               4044          21         11.0 2025-07-27          10
# 3                714          19         13.0 2025-10-29           1
# 4               1394           8          7.0 2025-12-01           1
# 5               2644           8         10.0 2025-01-16           1
# ...              ...         ...          ...        ...         ...
# 981              416           5          NaN 2025-11-20           5
# 982             4005          11          NaN 2025-04-19          10
# 983             4061           9          NaN 2025-10-09          10
# 984             3299           6          NaN 2025-07-23           3
# 985             1766          22          NaN 2025-12-25           6
#
#           valor_total canal_aquisicao               nome_produto    categoria  \
# id_venda
# 1             2623.20         Inbound            GS Engage - Hic         SaaS
# 2             7295.70        Outbound         High Growth - Nisi  Consultoria
# 3              142.35        Outbound    Station AI - Blanditiis         SaaS
# 4              871.78        Outbound        GS Engage - Commodi         SaaS
# 5              871.78        Outbound        GS Engage - Commodi         SaaS
# ...               ...             ...                        ...          ...
# 981             77.35         Inbound     Station AI - Similique         SaaS
# 982           2324.10         Inbound  Demanda Infinita - Maxime  Treinamento
# 983            401.90        Outbound     GS Engage - Doloremque         SaaS
# 984            920.04        Outbound         High Growth - Quis  Consultoria
# 985           5679.00        Outbound          High Growth - Est  Consultoria
#
#           preco_unitario  custo_unitario  lucro_total  margem_lucro
# id_venda
# 1                 655.80          537.76       472.16     17.999390
# 2                 729.57          437.74      2918.30     40.000274
# 3                 142.35          106.76        35.59     25.001756
# 4                 871.78          531.79       339.99     38.999518
# 5                 871.78          531.79       339.99     38.999518
# ...                  ...             ...          ...           ...
# 981                15.47            9.59        29.40     38.009050
# 982               232.41          204.52       278.90     12.000344
# 983                40.19           29.34       108.50     26.996765
# 984               306.68          239.21       202.41     22.000130
# 985               946.50          577.37      2214.78     38.999472
#
# [985 rows x 13 columns]

# %%
#Analisando os valores nulos na coluna id_campanha. Possivelmente vendas sem a utilização de campanhas.
vendas_produtos[vendas_produtos['id_campanha'].isnull()].head(5)
# Out:
#           id_cliente  id_produto  id_campanha data_venda  quantidade  \
# id_venda
# 658              767           6          NaN 2025-11-18           1
# 659              725          18          NaN 2025-08-02           1
# 660             4624          13          NaN 2025-08-17           3
# 661              860          11          NaN 2025-03-15           1
# 662             4016           9          NaN 2025-02-21           7
#
#           valor_total canal_aquisicao               nome_produto    categoria  \
# id_venda
# 658            306.68        Outbound         High Growth - Quis  Consultoria
# 659            732.90        Outbound         High Growth - Quis  Consultoria
# 660           1967.40         Inbound            GS Engage - Hic         SaaS
# 661            232.41        Outbound  Demanda Infinita - Maxime  Treinamento
# 662            281.33         Inbound     GS Engage - Doloremque         SaaS
#
#           preco_unitario  custo_unitario  lucro_total  margem_lucro
# id_venda
# 658               306.68          239.21        67.47     22.000130
# 659               732.90          410.42       322.48     44.000546
# 660               655.80          537.76       354.12     17.999390
# 661               232.41          204.52        27.89     12.000344
# 662                40.19           29.34        75.95     26.996765

# %%
# Selectionando os tops 5 produtos
top5_produtos = vendas_produtos['nome_produto'].value_counts().head(5).index

# Filtrando as vendas dos top 5 produtos
vendas_top5 = vendas_produtos[vendas_produtos['nome_produto'].isin(top5_produtos)]

# Agrupando e calcula métricas adicionais
resumo_top5 = vendas_top5.groupby('nome_produto')['margem_lucro'].mean().sort_values(ascending=False).round(1)
resumo_top5
# Out:
# nome_produto
# Station AI - Harum        48.0
# High Growth - Nisi        40.0
# High Growth - Quis        28.0
# GS Engage - Doloremque    27.0
# Imersão - Aliquam         17.0
# Name: margem_lucro, dtype: float64

# %%
fig = px.bar(resumo_top5, title='Lucro médio por Produto')
fig.update_layout(xaxis_title='Produto', yaxis_title='Lucro médio')
fig.update_legends(title_text='Legenda:')
fig.update_traces(texttemplate='%{y}%')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="38d2f2a2-4f45-4fca-a68c-755188e06454" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38d2f2a2-4f45-4fca-a68c-755188e06454")) {                    Plotly.newPlot(                        "38d2f2a2-4f45-4fca-a68c-755188e06454",                        [{"alignmentgroup":"True","hovertemplate":"variable=margem_lucro\u003cbr\u003enome_produto=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"margem_lucro","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"margem_lucro","offsetgroup":"margem_lucro","orientation":"v","showlegend":true,"textposition":"auto","x":["Station AI - Harum","High Growth - Nisi","High Growth - Quis","GS Engage - Doloremque","Imersão - Aliquam"],"xaxis":"x","y":[48.0,40.0,28.0,27.0,17.0],"yaxis":"y","type":"bar","texttemplate":"%{y}%"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"colo ...

# %% [markdown]
# ---

# %% [markdown]
# 3. Segmentação de Clientes:
# Compare o ticket médio entre os clientes dos segmentos B2B e B2C.

# %%
vendas_clientes = df_vendas.join(df_clientes.set_index('id_cliente'), on='id_cliente', how='left')
vendas_clientes.set_index('id_venda', inplace=True)
# Convert 'data_venda' to datetime after the join
vendas_clientes['data_venda'] = pd.to_datetime(vendas_clientes['data_venda'])

# %%
vendas_clientes
# Out:
#           id_cliente  id_produto  id_campanha data_venda  quantidade  \
# id_venda
# 1                273          13          8.0 2025-06-07           4
# 2               4044          21         11.0 2025-07-27          10
# 3                714          19         13.0 2025-10-29           1
# 4               1394           8          7.0 2025-12-01           1
# 5               2644           8         10.0 2025-01-16           1
# ...              ...         ...          ...        ...         ...
# 981              416           5          NaN 2025-11-20           5
# 982             4005          11          NaN 2025-04-19          10
# 983             4061           9          NaN 2025-10-09          10
# 984             3299           6          NaN 2025-07-23           3
# 985             1766          22          NaN 2025-12-25           6
#
#           valor_total canal_aquisicao                         nome  \
# id_venda
# 1             2623.20         Inbound                 Arthur Ramos
# 2             7295.70        Outbound      Dra. Heloísa Montenegro
# 3              142.35        Outbound         João Guilherme Porto
# 4              871.78        Outbound     Srta. Caroline Rodrigues
# 5              871.78        Outbound                   Ravi Porto
# ...               ...             ...                          ...
# 981             77.35         Inbound       Maria Fernanda Fonseca
# 982           2324.10         Inbound          Dra. Vitória Macedo
# 983            401.90        Outbound  Dr. Arthur Gabriel Ferreira
# 984            920.04        Outbound                 Joaquim Lima
# 985           5679.00        Outbound              Giovanna da Paz
#
#                      cidade segmento
# id_venda
# 1                Cavalcanti      B2C
# 2                    Mendes      B2B
# 3                   Cardoso      B2C
# 4         Azevedo de Moraes      B2C
# 5           Barros do Campo      B2C
# ...                     ...      ...
# 981         Lima das Pedras      B2B
# 982                 Andrade      B2C
# 983       Montenegro Grande      B2B
# 984           Lima da Serra      B2C
# 985                  Mendes      B2B
#
# [985 rows x 10 columns]

# %%
ticket_por_cliente = (
    vendas_clientes
        .groupby('segmento')
        .agg(
            faturamento_total=('valor_total', 'sum'),
            numero_vendas=('valor_total', 'count')
        )
        .assign(ticket_medio=lambda x: (x['faturamento_total'] / x['numero_vendas']).round(2))
        .reset_index()
        .sort_values('ticket_medio', ascending=False)
)

# %%
ticket_por_cliente
# Out:
#   segmento  faturamento_total  numero_vendas  ticket_medio
# 0      B2B         1215913.12            491       2476.40
# 1      B2C         1215108.93            494       2459.73

# %%
fig = px.box(ticket_por_cliente, x='segmento', y='ticket_medio', title='Ticket médio por segmento de cliente')
fig.update_layout(xaxis_title='Segmento', yaxis_title='Ticket médio')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2180512d-6b19-43a8-a7d9-e98f1d34578d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2180512d-6b19-43a8-a7d9-e98f1d34578d")) {                    Plotly.newPlot(                        "2180512d-6b19-43a8-a7d9-e98f1d34578d",                        [{"alignmentgroup":"True","hovertemplate":"segmento=%{x}\u003cbr\u003eticket_medio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["B2B","B2C"],"x0":" ","xaxis":"x","y":[2476.4,2459.73],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{" ...

# %% [markdown]
# ---

# %% [markdown]
# 4. Sazonalidade:
# Analise o padrão de vendas ao longo do ano, identificando picos e quedas, e proponha possíveis explicações baseadas no comportamento de compra.

# %%
# Definindo a coluna data_venda para o tipo datetime
df_vendas['data_venda'] =  pd.to_datetime(df_vendas['data_venda'])

# %%
# Agrupar por mês e somar o valor total
vendas_mensais = df_vendas.groupby(df_vendas['data_venda'].dt.to_period('M'))['valor_total'].sum().reset_index()

# Converter de Period para datetime para usar no gráfico
vendas_mensais['data_venda'] = vendas_mensais['data_venda'].dt.to_timestamp()

fig = px.line(
    vendas_mensais,
    x='data_venda',
    y='valor_total',
    markers=True,
    title='Padrão de Vendas ao Longo do Ano'
)

fig.update_layout(
    xaxis_title='Mês',
    yaxis_title='Valor Total de Vendas'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4938a9c0-20e1-4e6a-bf64-7d79958ef651" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4938a9c0-20e1-4e6a-bf64-7d79958ef651")) {                    Plotly.newPlot(                        "4938a9c0-20e1-4e6a-bf64-7d79958ef651",                        [{"hovertemplate":"data_venda=%{x}\u003cbr\u003evalor_total=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2025-01-01T00:00:00","2025-02-01T00:00:00","2025-03-01T00:00:00","2025-04-01T00:00:00","2025-05-01T00:00:00","2025-06-01T00:00:00","2025-07-01T00:00:00","2025-08-01T00:00:00","2025-09-01T00:00:00","2025-10-01T00:00:00","2025-11-01T00:00:00","2025-12-01T00:00:00"],"xaxis":"x","y":[250943.09,84476.61,112315.37,260171.73,125152.49,216617.25,348282.93,153385.02,274535.18,281580.93,217491.3,106070.15],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","m ...

# %%
# Agrupando por mês e segmento
vendas_por_segmento = (
    vendas_clientes
    .groupby([vendas_clientes['data_venda'].dt.to_period('M'), 'segmento'])['valor_total']
    .sum()
    .reset_index()
)

# Alterando de Period para datetime
vendas_por_segmento['data_venda'] = vendas_por_segmento['data_venda'].dt.to_timestamp()


fig = px.line(
    vendas_por_segmento,
    x='data_venda',
    y='valor_total',
    color='segmento',
    markers=True,
    title='Vendas por Segmento ao Longo do Ano'
)

fig.update_layout(
    xaxis_title='Mês',
    yaxis_title='Valor Total de Vendas'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7cd65ec4-bcf1-4136-811b-6819de360a88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7cd65ec4-bcf1-4136-811b-6819de360a88")) {                    Plotly.newPlot(                        "7cd65ec4-bcf1-4136-811b-6819de360a88",                        [{"hovertemplate":"segmento=B2B\u003cbr\u003edata_venda=%{x}\u003cbr\u003evalor_total=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"B2B","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"B2B","orientation":"v","showlegend":true,"x":["2025-01-01T00:00:00","2025-02-01T00:00:00","2025-03-01T00:00:00","2025-04-01T00:00:00","2025-05-01T00:00:00","2025-06-01T00:00:00","2025-07-01T00:00:00","2025-08-01T00:00:00","2025-09-01T00:00:00","2025-10-01T00:00:00","2025-11-01T00:00:00","2025-12-01T00:00:00"],"xaxis":"x","y":[148483.13,33435.46,54231.89,136919.79,65111.590000000004,79292.84,170915.04,83409.05,129664.06,149837.47,121721.24,42891.56],"yaxis":"y","type":"scatter"},{"hovertemplate":"segmento=B2C\u003cbr\u003edata_venda=%{x}\u003cbr\u003evalor_total=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"B2C","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"B2C","orientation":"v","showlegend":true,"x":["2025-01-01T00:00:00","2025-02-01T00:00:00","2025-03-01T00:00:00","2025-04-01T00:00:00","2025-05-01T00:00:00","2025-06-01T00:00:00","2025-07-01T00:00:00","2025-08-01T00:00:00","2025-09-01T00:00:00","2025-10-01T00:00:00","2025-11-01T00:00:00","2025-12-01T00:00:00"],"xaxis":"x","y":[102459.96,51041.15,58083.48,123251.94,60040.9,137324.41,177367.89,69975.97,144871.12,131743.46,95770.06,63178.590000000004],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"], ...

# %% [markdown]
# Jan - No inicio do ano até fevereiro é possível notar uma queda, possívelmente devido as festas ocorridas no final do ano.
#
# Fev | Abr - Ocorre um aumento devido ao retorno da economia após as vendas do final ano. Durante esses meses ocorrem eventos promocionais e data comemorativas: Páscoa e carnaval.
#
# Abr | Maio - Há uma queda das vendas ocorrido, possívelmente, pela eventos promocionais para a data comemorativa de dias das mães.
#
# Mai | Jul - Aumento de vendas ocorrida devido as promoções de meio de ano. E também datas comemorativas como dias dos namorados e festas juninas.
#
# Ago - Queda devido ao mês de Julho, muitas pessoas planejam viagens em familia.
#
# Set | Out - volta a subir  pode estar ligado a campanhas de primavera ou volta às aulas.
#
# No mês de novembro ocorre uma "anormalidade" nas vendas, pois o padrão é as vendas aumentarem. interessante, porque em muitos setores dezembro é pico (Natal). Aqui, pode indicar que seu negócio não é fortemente atrelado ao varejo de fim de ano

# %% [markdown]
# # B. Análise de Marketing

# %% [markdown]
# 5. Eficiência das Campanhas:
# Determine quais campanhas tiveram maior taxa de conversão, relacionando o número de interações do tipo "Conversão" com o orçamento e custo das campanhas.

# %%
# Relacionando as tabelas
campanhas_marketing = df_campanhas_marketing.join(df_interacoes_marketing.set_index('id_campanha'), on='id_campanha', how='left')

# Removendo o nome campanha de cada célula, mnatendo somente da coluna
df_campanhas_marketing['nome_campanha'] = df_campanhas_marketing['nome_campanha'].str.replace('Campanha', '')

# %%
campanhas_marketing.to_excel('campanhas_marketing.xlsx', index=False)

# %%
campanhas_marketing
# Out:
#     id_campanha nome_campanha canal_marketing data_inicio   data_fim  \
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# ..          ...           ...             ...         ...        ...
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
#
#     orcamento    custo  id_interacao  id_cliente data_interacao tipo_interacao
# 0    10168.22  2988.19            14        3189     2025-06-19   Visualização
# 0    10168.22  2988.19            51        1758     2025-04-21   Visualização
# 0    10168.22  2988.19            64         206     2025-01-21   Visualização
# 0    10168.22  2988.19            72        4202     2025-05-24   Visualização
# 0    10168.22  2988.19            80        4915     2025-07-09      Conversão
# ..        ...      ...           ...         ...            ...            ...
# 19    9292.03  9555.82         14811        2732     2025-05-19      Conversão
# 19    9292.03  9555.82         14842        1990     2025-09-25   Visualização
# 19    9292.03  9555.82         14892        4426     2025-03-05         Clique
# 19    9292.03  9555.82         14936        2488     2025-08-15   Visualização
# 19    9292.03  9555.82         14975        2246     2025-08-15   Visualização
#
# [15000 rows x 11 columns]

# %%
taxa_conversao = (
    campanhas_marketing
    .groupby(['nome_campanha', 'id_campanha', 'orcamento', 'custo'])
    .agg(
        total_interacoes = ('tipo_interacao', 'count'),
        total_conversoes = ('tipo_interacao', lambda x: (x == 'Conversão').sum())
    )
)

taxa_conversao['taxa_conversao_%'] = (
    (taxa_conversao['total_conversoes'] / taxa_conversao['total_interacoes']) * 100
)

taxa_conversao = taxa_conversao.sort_values('taxa_conversao_%', ascending=False).reset_index()
taxa_conversao
# Out:
#            nome_campanha  id_campanha  orcamento     custo  total_interacoes  \
# 0         Campanha Nobis            7    1606.62   1595.67               749
# 1         Campanha Ipsam           20    9292.03   9555.82               744
# 2    Campanha Aspernatur           13    7732.77   5485.33               758
# 3         Campanha Velit            1   10168.22   2988.19               699
# 4          Campanha Sunt            4   18442.84   6574.57               786
# 5        Campanha Libero            8   14551.62   1653.04               778
# 6          Campanha Quam            2   14307.26  16227.62               734
# 7      Campanha Quisquam           16    3726.32    485.79               736
# 8          Campanha Odio            6   19596.79  21774.87               686
# 9     Campanha Explicabo           15   15507.16   5054.31               803
# 10  Campanha Perferendis           18   18586.32   4101.02               767
# 11       Campanha Labore           17   11166.70  14039.36               769
# 12          Campanha Quo           12    7736.67   8612.92               700
# 13    Campanha Quibusdam           19   13244.99  13887.50               745
# 14         Campanha Esse           10    7460.03   5966.11               793
# 15   Campanha Recusandae            9   18100.50  10403.76               725
# 16        Campanha Nihil           14   11069.56  13394.57               777
# 17          Campanha Sit           11    6850.80   8104.37               743
# 18      Campanha Facilis            3   18522.42   7259.41               742
# 19   Campanha Temporibus            5    2626.23   1524.82               766
#
#     total_conversoes  taxa_conversao_%
# 0                 90         12.016021
# 1                 89         11.962366
# 2                 88         11.609499
# 3                 80         11.444921
# 4                 89         11.323155
# 5                 87         11.182519
# 6                 80         10.899183
# 7                 79         10.733696
# 8                 73         10.641399
# 9                 82         10.211706
# 10                78         10.169492
# 11                76          9.882965
# 12                69          9.857143
# 13                73          9.798658
# 14                77          9.709962
# 15                69          9.517241
# 16                73          9.395109
# 17                64          8.613728
# 18                59          7.951482
# 19                58          7.571802

# %%
taxa_conversao.to_excel('taxa_conversao.xlsx', index=False)

# %% [markdown]
# 6. Canais de Marketing:
# Analise qual canal de marketing (Email, Google Ads, Meta Ads, etc.) gera maior engajamento dos clientes, baseado nas interações registradas.

# %%
canal_interacao = campanhas_marketing.groupby('canal_marketing')['tipo_interacao'].value_counts().sort_values(ascending=False)
canal_interacao
# Out:
# canal_marketing  tipo_interacao
# Meta Ads         Visualização      4624
# Email            Visualização      3235
# Google Ads       Visualização      2632
# Meta Ads         Clique            1363
# Email            Clique             899
# Google Ads       Clique             714
# Meta Ads         Conversão          679
# Email            Conversão          453
# Google Ads       Conversão          401
# Name: count, dtype: int64

# %%
fig = px.bar(canal_interacao, x='canal_marketing', y='count', color='tipo_interacao', text="count")
fig.update_traces(texttemplate='%{text:.0f}', textposition='inside')
fig.update_layout(
    xaxis_title='Canal de Marketing',
    yaxis_title='Quantidade de Interações',
    title='Quantidade de Interações por Canal de Marketing'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1d98c398-9c84-4cfe-ba44-d8b343541ca1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d98c398-9c84-4cfe-ba44-d8b343541ca1")) {                    Plotly.newPlot(                        "1d98c398-9c84-4cfe-ba44-d8b343541ca1",                        [{"alignmentgroup":"True","hovertemplate":"tipo_interacao=Visualização\u003cbr\u003ecanal_marketing=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Visualização","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Visualização","offsetgroup":"Visualização","orientation":"v","showlegend":true,"text":[3235.0,2632.0,4624.0],"textposition":"inside","x":["Email","Google Ads","Meta Ads"],"xaxis":"x","y":[3235,2632,4624],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"tipo_interacao=Clique\u003cbr\u003ecanal_marketing=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Clique","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Clique","offsetgroup":"Clique","orientation":"v","showlegend":true,"text":[899.0,714.0,1363.0],"textposition":"inside","x":["Email","Google Ads","Meta Ads"],"xaxis":"x","y":[899,714,1363],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"tipo_interacao=Conversão\u003cbr\u003ecanal_marketing=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Conversão","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Conversão","offsetgroup":"Conversão","orientation":"v","showlegend":true,"text":[453.0,401.0,679.0],"textposition":"inside","x":["Email","Google Ads","Meta Ads"],"xaxis":"x","y":[453,401,679],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444 ...

# %% [markdown]
# # C. Análise Integrada (Vendas e Marketing)

# %% [markdown]
# 7. Relação Temporal:
# Investigue se há um aumento nas vendas de determinados produtos logo após o início de uma campanha de marketing.

# %%
# Definindo as colunas de datas(object) para datetime
df_campanhas_marketing['data_inicio'] = pd.to_datetime(df_campanhas_marketing['data_inicio'])
df_campanhas_marketing['data_fim'] = pd.to_datetime(df_campanhas_marketing['data_fim'])

# %%
#Relacionando as tabelas campanhas com vendas
df_campanhas_vendas = df_campanhas_marketing.join(df_vendas.set_index('id_campanha'), on='id_campanha', how='left')
df_campanhas_vendas
# Out:
#     id_campanha nome_campanha canal_marketing data_inicio   data_fim  \
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# ..          ...           ...             ...         ...        ...
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
#
#     orcamento    custo  id_venda  id_cliente  id_produto data_venda  \
# 0    10168.22  2988.19         6        2646          20 2025-07-25
# 0    10168.22  2988.19         9        1743          13 2025-07-07
# 0    10168.22  2988.19        24        3793          12 2025-07-25
# 0    10168.22  2988.19        51        3793          23 2025-07-16
# 0    10168.22  2988.19        77        3866           1 2025-07-12
# ..        ...      ...       ...         ...         ...        ...
# 19    9292.03  9555.82       580        4430           6 2025-10-25
# 19    9292.03  9555.82       622        2671          19 2025-10-18
# 19    9292.03  9555.82       632        4181          23 2025-10-28
# 19    9292.03  9555.82       641        4383          17 2025-11-12
# 19    9292.03  9555.82       642        4780          16 2025-10-19
#
#     quantidade  valor_total canal_aquisicao
# 0            4      2398.08         Inbound
# 0           10      6558.00        Outbound
# 0            6      5386.32         Inbound
# 0            8      2725.28         Inbound
# 0            1       755.55        Outbound
# ..         ...          ...             ...
# 19           2       613.36         Inbound
# 19           6       854.10        Outbound
# 19           3      1021.98        Outbound
# 19          10      3116.70        Outbound
# 19           1       467.21        Outbound
#
# [657 rows x 14 columns]

# %%
#Relaciondo
df_produtos_vendas = df_campanhas_vendas.join(df_produtos.set_index('id_produto'), on='id_produto', how='left')
df_produtos_vendas
# Out:
#     id_campanha nome_campanha canal_marketing data_inicio   data_fim  \
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# ..          ...           ...             ...         ...        ...
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
#
#     orcamento    custo  id_venda  id_cliente  id_produto data_venda  \
# 0    10168.22  2988.19         6        2646          20 2025-07-25
# 0    10168.22  2988.19         9        1743          13 2025-07-07
# 0    10168.22  2988.19        24        3793          12 2025-07-25
# 0    10168.22  2988.19        51        3793          23 2025-07-16
# 0    10168.22  2988.19        77        3866           1 2025-07-12
# ..        ...      ...       ...         ...         ...        ...
# 19    9292.03  9555.82       580        4430           6 2025-10-25
# 19    9292.03  9555.82       622        2671          19 2025-10-18
# 19    9292.03  9555.82       632        4181          23 2025-10-28
# 19    9292.03  9555.82       641        4383          17 2025-11-12
# 19    9292.03  9555.82       642        4780          16 2025-10-19
#
#     quantidade  valor_total canal_aquisicao                 nome_produto  \
# 0            4      2398.08         Inbound           Station AI - Harum
# 0           10      6558.00        Outbound              GS Engage - Hic
# 0            6      5386.32         Inbound  Demanda Infinita - Expedita
# 0            8      2725.28         Inbound        Growth Way - Mollitia
# 0            1       755.55        Outbound         Growth Way - Eveniet
# ..         ...          ...             ...                          ...
# 19           2       613.36         Inbound           High Growth - Quis
# 19           6       854.10        Outbound      Station AI - Blanditiis
# 19           3      1021.98        Outbound        Growth Way - Mollitia
# 19          10      3116.70        Outbound            Imersão - Aliquam
# 19           1       467.21        Outbound          High Growth - Rerum
#
#       categoria  preco_unitario  custo_unitario
# 0          SaaS          599.52          311.75
# 0          SaaS          655.80          537.76
# 0   Treinamento          897.72          646.36
# 0   Consultoria          340.66          197.58
# 0   Consultoria          755.55          551.55
# ..          ...             ...             ...
# 19  Consultoria          306.68          239.21
# 19         SaaS          142.35          106.76
# 19  Consultoria          340.66          197.58
# 19  Treinamento          311.67          258.69
# 19  Consultoria          467.21          247.62
#
# [657 rows x 18 columns]

# %%
df_produtos_vendas
# Out:
#     id_campanha nome_campanha canal_marketing data_inicio   data_fim  \
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# 0             1         Velit      Google Ads  2025-07-05 2025-07-30
# ..          ...           ...             ...         ...        ...
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 19           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
#
#     orcamento    custo  id_venda  id_cliente  id_produto data_venda  \
# 0    10168.22  2988.19         6        2646          20 2025-07-25
# 0    10168.22  2988.19         9        1743          13 2025-07-07
# 0    10168.22  2988.19        24        3793          12 2025-07-25
# 0    10168.22  2988.19        51        3793          23 2025-07-16
# 0    10168.22  2988.19        77        3866           1 2025-07-12
# ..        ...      ...       ...         ...         ...        ...
# 19    9292.03  9555.82       580        4430           6 2025-10-25
# 19    9292.03  9555.82       622        2671          19 2025-10-18
# 19    9292.03  9555.82       632        4181          23 2025-10-28
# 19    9292.03  9555.82       641        4383          17 2025-11-12
# 19    9292.03  9555.82       642        4780          16 2025-10-19
#
#     quantidade  valor_total canal_aquisicao                 nome_produto  \
# 0            4      2398.08         Inbound           Station AI - Harum
# 0           10      6558.00        Outbound              GS Engage - Hic
# 0            6      5386.32         Inbound  Demanda Infinita - Expedita
# 0            8      2725.28         Inbound        Growth Way - Mollitia
# 0            1       755.55        Outbound         Growth Way - Eveniet
# ..         ...          ...             ...                          ...
# 19           2       613.36         Inbound           High Growth - Quis
# 19           6       854.10        Outbound      Station AI - Blanditiis
# 19           3      1021.98        Outbound        Growth Way - Mollitia
# 19          10      3116.70        Outbound            Imersão - Aliquam
# 19           1       467.21        Outbound          High Growth - Rerum
#
#       categoria  preco_unitario  custo_unitario
# 0          SaaS          599.52          311.75
# 0          SaaS          655.80          537.76
# 0   Treinamento          897.72          646.36
# 0   Consultoria          340.66          197.58
# 0   Consultoria          755.55          551.55
# ..          ...             ...             ...
# 19  Consultoria          306.68          239.21
# 19         SaaS          142.35          106.76
# 19  Consultoria          340.66          197.58
# 19  Treinamento          311.67          258.69
# 19  Consultoria          467.21          247.62
#
# [657 rows x 18 columns]

# %%
# Filter sales within the campaign period
vendas_durante_campanha = df_produtos_vendas.loc[
    (df_produtos_vendas['data_venda'] >= df_produtos_vendas['data_inicio']) &
    (df_produtos_vendas['data_venda'] <= df_produtos_vendas['data_fim'])
]

vendas_antes_campanha = df_produtos_vendas.loc[
    (df_produtos_vendas['data_venda'] > df_produtos_vendas['data_fim'])
]
vendas_antes_campanha
# Out:
# Empty DataFrame
# Columns: [id_campanha, nome_campanha, canal_marketing, data_inicio, data_fim, orcamento, custo, id_venda, id_cliente, id_produto, data_venda, quantidade, valor_total, canal_aquisicao, nome_produto, categoria, preco_unitario, custo_unitario]
# Index: []

# %%
def classificar_periodo(row):
    if row["data_venda"] < row["data_inicio"]:
        return "antes"
    elif row["data_inicio"] <= row["data_venda"] <= row["data_fim"]:
        return "durante"
    else:
        return "depois"

df_produtos_vendas["periodo"] = df_produtos_vendas.apply(classificar_periodo, axis=1)

# Contar vendas por produto e período
resultado = df_produtos_vendas.groupby(["nome_produto", "periodo"]).size().reset_index()
print(resultado)
# Out:
#                    nome_produto  periodo   0
# 0   Demanda Infinita - Expedita  durante  24
# 1     Demanda Infinita - Maxime  durante  24
# 2           GS Engage - Commodi  durante  26
# 3        GS Engage - Doloremque  durante  30
# 4               GS Engage - Hic  durante  29
# 5              Growth Way - Aut  durante  31
# 6          Growth Way - Eveniet  durante  26
# 7             Growth Way - Modi  durante  28
# 8        Growth Way - Molestias  durante  28
# 9         Growth Way - Mollitia  durante  30
# 10            High Growth - Est  durante  24
# 11           High Growth - Nisi  durante  30
# 12           High Growth - Quis  durante  65
# 13    High Growth - Repellendus  durante  26
# 14          High Growth - Rerum  durante  22
# 15                  Imersão - A  durante  22
# 16            Imersão - Aliquam  durante  30
# 17         Imersão - Laboriosam  durante  24
# 18             Imersão - Maxime  durante  21
# 19      Station AI - Blanditiis  durante  25
# 20         Station AI - Dolorem  durante  29
# 21           Station AI - Harum  durante  34
# 22       Station AI - Similique  durante  29

# %% [markdown]
# 8. Análise Regional:
# Explore se determinadas cidades apresentam melhor resposta às campanhas de marketing e como isso se reflete nas vendas.

# %%
df_metrica_por_cidade = campanhas_marketing.join(df_clientes.set_index('id_cliente'), on='id_cliente', how='left')

# %%
df_vendas_por_cidade = df_campanhas_vendas.join(df_clientes.set_index('id_cliente'), on='id_cliente', how='left')

# %%
df_metrica_cidade = df_vendas_por_cidade.join(df_interacoes_marketing.set_index('id_campanha'), on='id_campanha', how='left', lsuffix='_vendas', rsuffix='_interacoes')

# %%
agregado_cidade = df_metrica_cidade.groupby('cidade').agg(
    total_interacoes = ('tipo_interacao', 'count'),
    total_conversoes = ('tipo_interacao', lambda x: (x == 'Conversão').sum()),
    total_vendas = ('valor_total', 'sum'),
    total_custo = ('custo', 'sum')
).reset_index()


agregado_cidade['taxa_conversao_%'] = (
    agregado_cidade['total_conversoes'] / agregado_cidade['total_interacoes'] * 100
)


agregado_cidade['custo_por_conversao'] = np.where(
    agregado_cidade['total_conversoes'] > 0,
    agregado_cidade['total_custo'] / agregado_cidade['total_conversoes'],
    np.nan
)

agregado_cidade['roas'] = np.where(
    agregado_cidade['total_custo'] > 0,
    agregado_cidade['total_vendas'] / agregado_cidade['total_custo'],
    np.nan
)



agregado_cidade = agregado_cidade.head(5).sort_values(ascending=False, by='taxa_conversao_%').round(2)

# %%
agregado_cidade
# Out:
#                 cidade  total_interacoes  total_conversoes  total_vendas  \
# 1          Albuquerque              1564               176    3198475.22
# 2              Almeida              2216               247    3882427.36
# 4     Almeida do Galho               734                80     395207.62
# 3  Almeida de Silveira               736                79     902865.92
# 0                Abreu               725                69      22431.50
#
#    total_custo  taxa_conversao_%  custo_por_conversao  roas
# 1   6453677.14             11.25             36668.62  0.50
# 2   7824612.96             11.15             31678.59  0.50
# 4  11911073.08             10.90            148888.41  0.03
# 3    357541.44             10.73              4525.84  2.53
# 0   7542726.00              9.52            109314.87  0.00

# %%
fig = px.pie(
    agregado_cidade,
    names='cidade',
    values=agregado_cidade['taxa_conversao_%'],
    title='Taxa de Conversão por Cidade'
)
fig.update_traces(textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="034cd79e-b1b7-4674-9dc3-dd060d454152" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("034cd79e-b1b7-4674-9dc3-dd060d454152")) {                    Plotly.newPlot(                        "034cd79e-b1b7-4674-9dc3-dd060d454152",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"cidade=%{label}\u003cbr\u003etaxa_conversao_%=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Albuquerque","Almeida","Almeida do Galho","Almeida de Silveira","Abreu"],"legendgroup":"","name":"","showlegend":true,"values":[11.25,11.15,10.9,10.73,9.52],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scat ...

# %%
fig = px.bar(agregado_cidade, x='cidade', y='total_vendas', text='total_vendas')
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig.update_layout(
    xaxis_title='Cidade')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="daa824da-8cd6-400a-b28a-c13bcef89a14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("daa824da-8cd6-400a-b28a-c13bcef89a14")) {                    Plotly.newPlot(                        "daa824da-8cd6-400a-b28a-c13bcef89a14",                        [{"alignmentgroup":"True","hovertemplate":"cidade=%{x}\u003cbr\u003etotal_vendas=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[3198475.22,3882427.36,395207.62,902865.92,22431.5],"textposition":"outside","x":["Albuquerque","Almeida","Almeida do Galho","Almeida de Silveira","Abreu"],"xaxis":"x","y":[3198475.22,3882427.36,395207.62,902865.92,22431.5],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5E ...

# %%
df_principal = df_vendas.merge(df_produtos, on='id_produto', how='left')

# %%
df_principal = df_campanhas_marketing.merge(df_principal, on='id_campanha', how='left')

# %%
df_principal = df_principal.merge(df_clientes, on='id_cliente', how='left')

# %%
df_principal = df_principal.merge(df_interacoes_marketing, on='id_campanha', how='left')

# %%
df_principal
# Out:
#         id_campanha nome_campanha canal_marketing data_inicio   data_fim  \
# 0                 1         Velit      Google Ads  2025-07-05 2025-07-30
# 1                 1         Velit      Google Ads  2025-07-05 2025-07-30
# 2                 1         Velit      Google Ads  2025-07-05 2025-07-30
# 3                 1         Velit      Google Ads  2025-07-05 2025-07-30
# 4                 1         Velit      Google Ads  2025-07-05 2025-07-30
# ...             ...           ...             ...         ...        ...
# 493469           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 493470           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 493471           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 493472           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
# 493473           20         Ipsam        Meta Ads  2025-10-18 2025-11-16
#
#         orcamento    custo  id_venda  id_cliente_x  id_produto  ...  \
# 0        10168.22  2988.19         6          2646          20  ...
# 1        10168.22  2988.19         6          2646          20  ...
# 2        10168.22  2988.19         6          2646          20  ...
# 3        10168.22  2988.19         6          2646          20  ...
# 4        10168.22  2988.19         6          2646          20  ...
# ...           ...      ...       ...           ...         ...  ...
# 493469    9292.03  9555.82       642          4780          16  ...
# 493470    9292.03  9555.82       642          4780          16  ...
# 493471    9292.03  9555.82       642          4780          16  ...
# 493472    9292.03  9555.82       642          4780          16  ...
# 493473    9292.03  9555.82       642          4780          16  ...
#
#           categoria  preco_unitario  custo_unitario                    nome  \
# 0              SaaS          599.52          311.75  Maria Fernanda Cardoso
# 1              SaaS          599.52          311.75  Maria Fernanda Cardoso
# 2              SaaS          599.52          311.75  Maria Fernanda Cardoso
# 3              SaaS          599.52          311.75  Maria Fernanda Cardoso
# 4              SaaS          599.52          311.75  Maria Fernanda Cardoso
# ...             ...             ...             ...                     ...
# 493469  Consultoria          467.21          247.62        Dra. Laura Nunes
# 493470  Consultoria          467.21          247.62        Dra. Laura Nunes
# 493471  Consultoria          467.21          247.62        Dra. Laura Nunes
# 493472  Consultoria          467.21          247.62        Dra. Laura Nunes
# 493473  Consultoria          467.21          247.62        Dra. Laura Nunes
#
#          cidade segmento  id_interacao  id_cliente_y data_interacao  \
# 0       Rezende      B2B            14          3189     2025-06-19
# 1       Rezende      B2B            51          1758     2025-04-21
# 2       Rezende      B2B            64           206     2025-01-21
# 3       Rezende      B2B            72          4202     2025-05-24
# 4       Rezende      B2B            80          4915     2025-07-09
# ...         ...      ...           ...           ...            ...
# 493469    Rocha      B2C         14811          2732     2025-05-19
# 493470    Rocha      B2C         14842          1990     2025-09-25
# 493471    Rocha      B2C         14892          4426     2025-03-05
# 493472    Rocha      B2C         14936          2488     2025-08-15
# 493473    Rocha      B2C         14975          2246     2025-08-15
#
#        tipo_interacao
# 0        Visualização
# 1        Visualização
# 2        Visualização
# 3        Visualização
# 4           Conversão
# ...               ...
# 493469      Conversão
# 493470   Visualização
# 493471         Clique
# 493472   Visualização
# 493473   Visualização
#
# [493474 rows x 25 columns]

# %%
df_principal.to_excel('df_principal.xlsx', index=False)
